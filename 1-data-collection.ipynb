# %% [markdown]
# # Bioinformatics: Drug discovery on CaM-kinase kinase beta protein

# %% [markdown]
# ## Data Collection

# %% [markdown]
# ### Libraries Required

# %%
# install ChEMBL web service package to retrieve the biological data
! pip install -q chembl_webresource_client
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 3.1 MB/s eta 0:00:00

# %%
# import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ### Searching for the target protein

# %%
# target search for CaMKK2
target = new_client.target
target_query = target.search('CaMKK2')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references           organism  \
# 0  [{'xref_id': 'CAMKK2', 'xref_name': None, 'xre...       Homo sapiens
# 1  [{'xref_id': 'O88831', 'xref_name': None, 'xre...  Rattus norvegicus
# 2                                                 []       Mus musculus
#
#                                            pref_name  score  \
# 0                             CaM-kinase kinase beta   12.0
# 1  Calcium/calmodulin-dependent protein kinase ki...   11.0
# 2  Calcium/calmodulin-dependent protein kinase ki...   11.0
#
#    species_group_flag target_chembl_id  \
# 0               False       CHEMBL5284
# 1               False    CHEMBL1795115
# 2               False    CHEMBL4295888
#
#                                    target_components     target_type  tax_id
# 0  [{'accession': 'Q96RR4', 'component_descriptio...  SINGLE PROTEIN    9606
# 1  [{'accession': 'O88831', 'component_descriptio...  SINGLE PROTEIN   10116
# 2  [{'accession': 'Q8C078', 'component_descriptio...  SINGLE PROTEIN   10090

# %%
# select and retrieve bioactivity data for CaM-kinase kinase beta (first entry)
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL5284'

# %%
# retrieve only bioactivity data for CHEMBL5284
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#                                          action_type activity_comment  \
# 0                                               None             None
# 1                                               None             None
# 2  {'action_type': 'ANTAGONIST', 'description': '...       Antagonist
#
#    activity_id activity_properties assay_chembl_id  \
# 0      2137123                  []    CHEMBL940168
# 1      2137359                  []    CHEMBL940168
# 2      2897276                  []   CHEMBL1051267
#
#                                    assay_description assay_type  \
# 0                           Inhibition of CaM-KKbeta          B
# 1                           Inhibition of CaM-KKbeta          B
# 2  Inhibition of CAMKKbeta in the presence of 20u...          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                    None                   None  BAO_0000190  ...
# 1                    None                   None  BAO_0000190  ...
# 2                    None                   None  BAO_0000190  ...
#
#   target_organism        target_pref_name target_tax_id text_value  toid  \
# 0    Homo sapiens  CaM-kinase kinase beta          9606       None  None
# 1    Homo sapiens  CaM-kinase kinase beta          9606       None  None
# 2    Homo sapiens  CaM-kinase kinase beta          9606       None  None
#
#    type  units    uo_units upper_value  value
# 0  IC50     nM  UO_0000065        None  200.0
# 1  IC50  ng/ml  UO_0000274        None   40.0
# 2  IC50     uM  UO_0000065        None   0.01
#
# [3 rows x 46 columns]

# %%
# check that all of the standard types are IC50
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Target: low as possible for standard value

# %%
# standard value represents potency; lower = better potency of the drug
df.standard_value.sort_values().head(10)
# Out:
# 1         0.04
# 32       1.585
# 28       1.995
# 45       1.995
# 2         10.0
# 55       100.0
# 20       100.0
# 128     1000.0
# 129    10000.0
# 57     10000.0
# Name: standard_value, dtype: object

# %% [markdown]
# ## Save the file

# %%
# save the data to CSV file
df.to_csv('CaMKK2_bioactivity_data.csv', index=False)

# %%
# copy the file to google drive to be accessible within colab
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# create a data folder in the colab notebook folder
! mkdir -p "/content/gdrive/My Drive/Colab Notebooks/data/"

# %%
# copy the file to the data folder
! cp CaMKK2_bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data/"

# %%
# list the files in data folder
! ls "/content/gdrive/My Drive/Colab Notebooks/data/"
# Out:
# CaMKK2_bioactivity_data.csv

# %%
# check the content of the file
! head "/content/gdrive/My Drive/Colab Notebooks/data/CaMKK2_bioactivity_data.csv"
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,,2137123,[],CHEMBL940168,Inhibition of CaM-KKbeta,B,,,BAO_0000190,BAO_0000357,single protein format,O=C(O)c1cc(NCc2cc(O)ccc2O)ccc1O,,,CHEMBL1145498,Proc Natl Acad Sci U S A,2007,"{'bei': '24.34', 'le': '0.46', 'lle': '4.59', 'sei': '6.09'}",CHEMBL319620,LAVENDUSTIN C,CHEMBL319620,6.70,0,http://www.openphacts.org/units/Nanomolar,705212,=,1,1,=,,IC50,nM,,200.0,CHEMBL5284,Homo sapiens,CaM-kinase kinase beta,9606,,,IC50,nM,UO_0000065,,200.0
# ,,2137359,[],CHEMBL940168,Inhibition of CaM-KKbeta,B,,,BAO_0000190,BAO_0000357,single protein format,CC(=O)O.O=C(O)c1ccc2c3c1cccc3c(=O)n1c3ccccc3nc21,,,CHEMBL1145498,Proc Natl Acad Sci U S A,2007,,CHEMBL265470,,CHEMBL1182777,,0,http://www.openphacts.org/units/MicrogramPerMilliliter,705270,=,1,1,=,,IC50,ug.mL-1,,0.04,CHEMBL5284,Homo sapiens,CaM-kinase kinase beta,9606,,,IC50,ng/ml,UO_0000274,,40.0
# "{'action_type': 'ANTAGONIST', 'description': 'Binds to a receptor and prevents activation by an agonist through competing for the binding site', 'parent_type': 'NEGATIVE MODULATOR'}",Antagonist,2897276,[],CHEMBL1051267,Inhibition of CAMKKbeta in the presence of 20uM ATP,B,,,BAO_0000190,BAO_0000357,single protein format,CC(=O)O.O=C(O)c1ccc2c3c1cccc3c(=O)n1c3ccccc3nc21,,,CHEMBL1150976,Biochem J,2007,"{'bei': '25.45', 'le': '0.46', 'lle': '4.71', 'sei': '11.16'}",CHEMBL265470,,CHEMBL1182777,8.00,0,http://www.openphacts.org/units/Nanomolar,845274,=,1,1,=,,IC50,nM,,10.0,CHEMBL5284,Homo sapiens,CaM-kinase kinase beta,9606,,,IC50,uM,UO_0000065,,0.01
# ,,6274565,[],CHEMBL1806284,Inhibition of CAMKKbeta,B,,,BAO_0000190,BAO_0000357,single protein format,CC(C)c1cnn2c(NCc3ccccc3)cc(N[C@@H](CO)[C@H](O)CO)nc12,,,CHEMBL1800061,J Med Chem,2010,"{'bei': '14.56', 'le': '0.27', 'lle': '4.02', 'sei': '4.88'}",CHEMBL1234833,,CHEMBL1234833,5.61,0,http://www.openphacts.org/units/Nanomolar,1441227,=,1,1,=,,IC50,nM,,2450.0,CHEMBL5284,Homo sapiens,CaM-kinase kinase beta,9606,,,IC50,nmol/L,UO_0000065,,2450.0
# ,,12183914,[],CHEMBL2211051,Inhibition of CAMKK2,B,,,BAO_0000190,BAO_0000357,single protein format,CC(C)(C)NS(=O)(=O)c1cncc(-c2ccn3nc(N)nc3c2)c1,,,CHEMBL2203257,Bioorg Med Chem Lett,2012,,CHEMBL2205766,,CHEMBL2205766,,0,http://www.openphacts.org/units/Nanomolar,1759115,<,1,1,>,,IC50,nM,,10000.0,CHEMBL5284,Homo sapiens,CaM-kinase kinase beta,9606,,,pIC50,,UO_0000065,,5.0
# ,,13490915,[],CHEMBL2446680,Inhibition of CAMKK2 (unknown origin),B,,,BAO_0000190,BAO_0000357,single protein format,CCc1ccc2nc(Nc3cc(Cc4ccccc4)nc(N[C@H]4CC[C@H](O)CC4)n3)sc2c1,,,CHEMBL2440060,ACS Med Chem Lett,2013,"{'bei': '14.58', 'le': '0.28', 'lle': '1.00', 'sei': '8.08'}",CHEMBL2441273,,CHEMBL2441273,6.70,0,http://www.openphacts.org/units/Nanomolar,1927543,=,1,1,=,,IC50,nM,,199.53,CHEMBL5284,Homo sapiens,CaM-kinase kinase beta,9606,,,pIC50,,UO_0000065,,6.7
# ,,16431759,[],CHEMBL3748651,Inhibition of human CAMKK2 using MBP as substrate,B,,,BAO_0000190,BAO_0000357,single protein format,Cn1c(=O)c(S(=O)(=O)c2ccc(F)cc2F)cc2cnc(Nc3ccc4[nH]ccc4c3)nc21,,,CHEMBL3745707,Bioorg Med Chem,2016,,CHEMBL3745885,,CHEMBL3745885,,0,http://www.openphacts.org/units/Nanomolar,2741358,>,1,1,>,,IC50,nM,,10000.0,CHEMBL5284,Homo sapiens,CaM-kinase kinase beta,9606,,,IC50,uM,UO_0000065,,10.0
# ,,16568749,[],CHEMBL3804022,Inhibition of full length recombinant human CaMKK2 expressed in insect Sf21 cells in presence of 2 uM CaM/[gamma32P]ATP by liquid scintillation counting analysis,B,,,BAO_0000190,BAO_0000219,cell-based format,COc1cccc(CN(CCN(CCN(C)C)Cc2ccccc2)Cc2ccccc2)c1,,,CHEMBL3797092,Eur J Med Chem,2016,"{'bei': '10.18', 'le': '0.19', 'lle': '-0.37', 'sei': '23.19'}",CHEMBL3798296,,CHEMBL3798296,4.39,0,http://www.openphacts.org/units/Nanomolar,2773198,=,1,1,=,,IC50,nM,,40400.0,CHEMBL5284,Homo sapiens,CaM-kinase kinase beta,9606,,,IC50,uM,UO_0000065,,40.4
# ,,18031637,[],CHEMBL4007691,Inhibition of CAMKK2 (unknown origin) after 60 mins by TR-FRET assay,B,,,BAO_0000190,BAO_0000357,single protein format,CC1(C)OCC(=O)Nc2cc(Nc3nc(NCC(F)(F)F)c4occc4n3)ccc21,,,CHEMBL4007384,Bioorg Med Chem Lett,2016,"{'bei': '13.57', 'le': '0.26', 'lle': '1.58', 'sei': '5.65'}",CHEMBL4069365,,CHEMBL4069365,5.72,0,http://www.openphacts.org/units/Nanomolar,2987739,=,1,1,=,,IC50,nM,,1910.0,CHEMBL5284,Homo sapiens,CaM-kinase kinase beta,9606,,,IC50,uM,UO_0000065,,1.91

# %% [markdown]
# ## Data Pre-Processing

# %% [markdown]
# ### Handling missing data

# %% [markdown]
# If any compounds has missing value for the **standard_value** column then drop it.

# %%
df.shape
# Out:
# (134, 46)

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2    {'action_type': 'ANTAGONIST', 'description': '...       Antagonist
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 129                                               None             None
# 130  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 131                                               None             None
# 132  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 133                                               None             None
#
#      activity_id                                activity_properties  \
# 0        2137123                                                 []
# 1        2137359                                                 []
# 2        2897276                                                 []
# 3        6274565                                                 []
# 4       12183914                                                 []
# ..           ...                                                ...
# 129     24953854  [{'comments': None, 'relation': None, 'result_...
# 130     24953858  [{'comments': None, 'relation': None, 'result_...
# 131     24954346  [{'comments': None, 'relation': None, 'result_...
# 132     24954353  [{'comments': None, 'relation': None, 'result_...
# 133     24958002  [{'comments': None, 'relation': None, 'result_...
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL940168                           Inhibition of CaM-KKbeta
# 1      CHEMBL940168                           Inhibition of CaM-KKbeta
# 2     CHEMBL1051267  Inhibition of CAMKKbeta in the presence of 20u...
# 3     CHEMBL1806284                            Inhibition of CAMKKbeta
# 4     CHEMBL2211051                               Inhibition of CAMKK2
# ..              ...                                                ...
# 129   CHEMBL5210020  Affinity Phenotypic Cellular interaction (West...
# 130   CHEMBL5210024  Affinity Phenotypic Cellular interaction (West...
# 131   CHEMBL5210464  Affinity Biochemical interaction (Enzymatic ac...
# 132   CHEMBL5210471  Affinity Biochemical interaction (Enzymatic ac...
# 133   CHEMBL5213074  Selectivity interaction (ActivX KiNative profi...
#
#     assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0            B                    None                   None  BAO_0000190
# 1            B                    None                   None  BAO_0000190
# 2            B                    None                   None  BAO_0000190
# 3            B                    None                   None  BAO_0000190
# 4            B                    None                   None  BAO_0000190
# ..         ...                     ...                    ...          ...
# 129          B                    None                   None  BAO_0000190
# 130          B                    None                   None  BAO_0000190
# 131          B                    None                   None  BAO_0000190
# 132          B                    None                   None  BAO_0000190
# 133          B                    None                   None  BAO_0000190
#
#      ... target_organism        target_pref_name target_tax_id text_value  \
# 0    ...    Homo sapiens  CaM-kinase kinase beta          9606       None
# 1    ...    Homo sapiens  CaM-kinase kinase beta          9606       None
# 2    ...    Homo sapiens  CaM-kinase kinase beta          9606       None
# 3    ...    Homo sapiens  CaM-kinase kinase beta          9606       None
# 4    ...    Homo sapiens  CaM-kinase kinase beta          9606       None
# ..   ...             ...                     ...           ...        ...
# 129  ...    Homo sapiens  CaM-kinase kinase beta          9606       None
# 130  ...    Homo sapiens  CaM-kinase kinase beta          9606       None
# 131  ...    Homo sapiens  CaM-kinase kinase beta          9606       None
# 132  ...    Homo sapiens  CaM-kinase kinase beta          9606       None
# 133  ...    Homo sapiens  CaM-kinase kinase beta          9606       None
#
#      toid   type   units    uo_units upper_value    value
# 0    None   IC50      nM  UO_0000065        None    200.0
# 1    None   IC50   ng/ml  UO_0000274        None     40.0
# 2    None   IC50      uM  UO_0000065        None     0.01
# 3    None   IC50  nmol/L  UO_0000065        None   2450.0
# 4    None  pIC50    None  UO_0000065        None      5.0
# ..    ...    ...     ...         ...         ...      ...
# 129  None   IC50      nM  UO_0000065        None  10000.0
# 130  None   IC50      nM  UO_0000065        None   1600.0
# 131  None   IC50      nM  UO_0000065        None  27000.0
# 132  None   IC50      nM  UO_0000065        None     30.0
# 133  None   IC50      uM  UO_0000065        None      1.1
#
# [133 rows x 46 columns]

# %% [markdown]
# There is one row removed which doesn't have a standard value.

# %% [markdown]
# ### Labeling compounds as either active, inactive, or intermediate

# %% [markdown]
# **IC50** - "half-maximal inhibitory concentration" <br>
# - to quantify potency of a substance in inhibiting a specific biological or biochemical function.
# - if we want to treat a disease/disorder with a drug, knowing which compound can inhibit the protein related to this will help
# - tells us how well a drug works at stopping a disease, and a lower IC50 means the drug can do its job with less effort (more effective)

# %% [markdown]
# The bioactivity data is in the IC50 unit. Compounds having values LESS than 1000 nM will be considered to be **active** while those GREATER than 10,000 nM will be considered to be **inactive**. As for those values in BETWEEN 1,000 and 10,000 nM will be referred to as **intermediate**. - *From Data Professor*

# %% [markdown]
# In simpler terms <br>
# 1. **Active** - the drug works very well at a small amount. <br>
# 2. **Inactive** - the drug doesn't work at all, even at a large amount. <br>
# 3. **Intermediate** - the drug works, but not as effective as an active drug.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# ### Iterate the molecule_chembl_id, canonical_smiles, and standard_value columns to a list

# %% [markdown]
# **molecule_chembl_id** - unique identification number of each molecule

# %%
df2.molecule_chembl_id
# Out:
# 0       CHEMBL319620
# 1       CHEMBL265470
# 2       CHEMBL265470
# 3      CHEMBL1234833
# 4      CHEMBL2205766
#            ...
# 129    CHEMBL4787282
# 130    CHEMBL4745471
# 131    CHEMBL4787282
# 132    CHEMBL4745471
# 133    CHEMBL4062218
# Name: molecule_chembl_id, Length: 133, dtype: object

# %% [markdown]
# **canonical_smiles** - SMILES (Simplified Molecular Input Line Entry System) <br>
# - standardized way of representing chemical structures as text strings <br>
# - notation for describing molecules <br>
# - "canonical" part ensures each unique molecule has only one possible SMILES representation for easier comparison

# %% [markdown]
# **Note:** In drug discovery, we aim to identify compounds with lowest IC50 value against the target protein. A lower IC50 indicates that a smaller amount of the compound is needed to achieve a significant inhibitory effect, which can be advantageous in terms of dosage and potential side effects.

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL319620                    O=C(O)c1cc(NCc2cc(O)ccc2O)ccc1O
# 1         CHEMBL265470   CC(=O)O.O=C(O)c1ccc2c3c1cccc3c(=O)n1c3ccccc3nc21
# 2         CHEMBL265470   CC(=O)O.O=C(O)c1ccc2c3c1cccc3c(=O)n1c3ccccc3nc21
# 3        CHEMBL1234833  CC(C)c1cnn2c(NCc3ccccc3)cc(N[C@@H](CO)[C@H](O)...
# 4        CHEMBL2205766      CC(C)(C)NS(=O)(=O)c1cncc(-c2ccn3nc(N)nc3c2)c1
# ..                 ...                                                ...
# 129      CHEMBL4787282        O=C(O)c1ccc(-c2coc3ncc(-c4ccccc4)cc23)cc1Cl
# 130      CHEMBL4745471  Cc1cccc(-c2cnc3occ(-c4ccc(C(=O)O)c(C5CCCC5)c4)...
# 131      CHEMBL4787282        O=C(O)c1ccc(-c2coc3ncc(-c4ccccc4)cc23)cc1Cl
# 132      CHEMBL4745471  Cc1cccc(-c2cnc3occ(-c4ccc(C(=O)O)c(C5CCCC5)c4)...
# 133      CHEMBL4062218  CNC(=O)c1ccc(Nc2nc(OC3CCCC3)c3c(-c4ccc5nc(C)oc...
#
#     standard_value
# 0            200.0
# 1             0.04
# 2             10.0
# 3           2450.0
# 4          10000.0
# ..             ...
# 129        10000.0
# 130         1600.0
# 131        27000.0
# 132           30.0
# 133         1100.0
#
# [133 rows x 3 columns]

# %%
# combine bioactivity column with the created dataframe
df3['bioactivity_class'] = bioactivity_class
df3
# Out:
# <ipython-input-30-48ebc6e76f32>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['bioactivity_class'] = bioactivity_class
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL319620                    O=C(O)c1cc(NCc2cc(O)ccc2O)ccc1O
# 1         CHEMBL265470   CC(=O)O.O=C(O)c1ccc2c3c1cccc3c(=O)n1c3ccccc3nc21
# 2         CHEMBL265470   CC(=O)O.O=C(O)c1ccc2c3c1cccc3c(=O)n1c3ccccc3nc21
# 3        CHEMBL1234833  CC(C)c1cnn2c(NCc3ccccc3)cc(N[C@@H](CO)[C@H](O)...
# 4        CHEMBL2205766      CC(C)(C)NS(=O)(=O)c1cncc(-c2ccn3nc(N)nc3c2)c1
# ..                 ...                                                ...
# 129      CHEMBL4787282        O=C(O)c1ccc(-c2coc3ncc(-c4ccccc4)cc23)cc1Cl
# 130      CHEMBL4745471  Cc1cccc(-c2cnc3occ(-c4ccc(C(=O)O)c(C5CCCC5)c4)...
# 131      CHEMBL4787282        O=C(O)c1ccc(-c2coc3ncc(-c4ccccc4)cc23)cc1Cl
# 132      CHEMBL4745471  Cc1cccc(-c2cnc3occ(-c4ccc(C(=O)O)c(C5CCCC5)c4)...
# 133      CHEMBL4062218  CNC(=O)c1ccc(Nc2nc(OC3CCCC3)c3c(-c4ccc5nc(C)oc...
#
#     standard_value bioactivity_class
# 0            200.0            active
# 1             0.04            active
# 2             10.0            active
# 3           2450.0      intermediate
# 4          10000.0          inactive
# ..             ...               ...
# 129        10000.0          inactive
# 130         1600.0      intermediate
# 131        27000.0          inactive
# 132           30.0            active
# 133         1100.0      intermediate
#
# [133 rows x 4 columns]

# %% [markdown]
# ### Save the preprocessed file

# %%
# save the preprocessed dataframe to a CSV file
df3.to_csv('CaMKK2_preprocessed_data.csv', index=False)

# %%
# add it to the google drive folder
! cp CaMKK2_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data/"

# %%
# check if the preprocessed file is in the data
! ls "/content/gdrive/My Drive/Colab Notebooks/data/"
# Out:
# CaMKK2_bioactivity_data.csv  CaMKK2_preprocessed_data.csv
