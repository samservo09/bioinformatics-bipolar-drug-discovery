# %% [markdown]
# # Bioinformatics: Drug discovery on CaM-kinase kinase beta protein

# %% [markdown]
# ## Data Collection

# %% [markdown]
# ### Libraries Required

# %%
# install ChEMBL web service package to retrieve the biological data
! pip install -q chembl_webresource_client
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 1.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 2.4 MB/s eta 0:00:00

# %%
# import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ### Searching for the target protein

# %%
# target search for CaMKK2
target = new_client.target
target_query = target.search('CaMKK2')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references           organism  \
# 0  [{'xref_id': 'CAMKK2', 'xref_name': None, 'xre...       Homo sapiens
# 1  [{'xref_id': 'O88831', 'xref_name': None, 'xre...  Rattus norvegicus
# 2                                                 []       Mus musculus
#
#                                            pref_name  score  \
# 0                             CaM-kinase kinase beta   12.0
# 1  Calcium/calmodulin-dependent protein kinase ki...   11.0
# 2  Calcium/calmodulin-dependent protein kinase ki...   11.0
#
#    species_group_flag target_chembl_id  \
# 0               False       CHEMBL5284
# 1               False    CHEMBL1795115
# 2               False    CHEMBL4295888
#
#                                    target_components     target_type  tax_id
# 0  [{'accession': 'Q96RR4', 'component_descriptio...  SINGLE PROTEIN    9606
# 1  [{'accession': 'O88831', 'component_descriptio...  SINGLE PROTEIN   10116
# 2  [{'accession': 'Q8C078', 'component_descriptio...  SINGLE PROTEIN   10090

# %%
# select and retrieve bioactivity data for CaM-kinase kinase beta (first entry)
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL5284'

# %%
# retrieve only bioactivity data for CHEMBL5284
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#                                          action_type activity_comment  \
# 0                                               None             None
# 1                                               None             None
# 2  {'action_type': 'ANTAGONIST', 'description': '...       Antagonist
#
#    activity_id activity_properties assay_chembl_id  \
# 0      2137123                  []    CHEMBL940168
# 1      2137359                  []    CHEMBL940168
# 2      2897276                  []   CHEMBL1051267
#
#                                    assay_description assay_type  \
# 0                           Inhibition of CaM-KKbeta          B
# 1                           Inhibition of CaM-KKbeta          B
# 2  Inhibition of CAMKKbeta in the presence of 20u...          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                    None                   None  BAO_0000190  ...
# 1                    None                   None  BAO_0000190  ...
# 2                    None                   None  BAO_0000190  ...
#
#   target_organism        target_pref_name target_tax_id text_value  toid  \
# 0    Homo sapiens  CaM-kinase kinase beta          9606       None  None
# 1    Homo sapiens  CaM-kinase kinase beta          9606       None  None
# 2    Homo sapiens  CaM-kinase kinase beta          9606       None  None
#
#    type  units    uo_units upper_value  value
# 0  IC50     nM  UO_0000065        None  200.0
# 1  IC50  ng/ml  UO_0000274        None   40.0
# 2  IC50     uM  UO_0000065        None   0.01
#
# [3 rows x 46 columns]

# %%
# check that all of the standard types are IC50
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
# standard value represents potency; lower = better potency of the drug
df.standard_value.head(3)
# Out:
# 0    200.0
# 1     0.04
# 2     10.0
# Name: standard_value, dtype: object

# %% [markdown]
# ## Data Pre-Processing
